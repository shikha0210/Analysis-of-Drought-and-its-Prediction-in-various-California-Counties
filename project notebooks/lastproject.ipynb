# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv (r'C:\Users\shahb\OneDrive\Desktop\data\soil_data.csv')
print(df)
# Out:
#        fips        lat         lon  elevation  slope1  slope2  slope3  slope4  \
# 0      1001  32.536382  -86.644490         63  0.0419  0.2788  0.2984  0.2497
# 1      1005  31.870670  -85.405456        146  0.0158  0.1868  0.5441  0.2424
# 2      1003  30.659218  -87.746067         52  0.0746  0.4370  0.4415  0.0469
# 3      1007  33.015893  -87.127148         93  0.0144  0.1617  0.3714  0.3493
# 4      1009  33.977448  -86.567246        198  0.0050  0.0872  0.2799  0.3576
# ...     ...        ...         ...        ...     ...     ...     ...     ...
# 3104  56037  41.660339 -108.875676       2085  0.0016  0.0281  0.1763  0.3554
# 3105  56039  44.049321 -110.588102       2564  0.0003  0.0026  0.0166  0.0722
# 3106  56043  43.878831 -107.669052       1417  0.0034  0.0470  0.2331  0.4099
# 3107  56041  41.284726 -110.558947       2327  0.0050  0.2009  0.4063  0.1858
# 3108  56045  43.846213 -104.570020       1276  0.0158  0.1958  0.6160  0.1688
#
# ...

# %%
fd = pd.read_csv (r"C:\Users\shahb\OneDrive\Desktop\data\full_dataset_CA_sorted.csv")
print(fd)
# Out:
#         Unnamed: 0  fips        date  PRECTOT      PS  QV2M   T2M  T2MDEW  \
# 0                0  6001  2000-01-01     0.12   99.77  5.97  7.89    6.28
# 1             5753  6001  2000-01-02     0.00  100.53  4.46  6.04    2.01
# 2             4620  6001  2000-01-03     0.10  100.92  4.85  7.73    3.39
# 3             5120  6001  2000-01-04     0.27  100.90  6.11  8.36    6.77
# 4             5119  6001  2000-01-05     0.00  100.52  4.13  7.32    0.75
# ...            ...   ...         ...      ...     ...   ...   ...     ...
# 444913      437633  6115  2020-12-27     0.00   95.37  4.26  5.23    0.91
# 444914      437632  6115  2020-12-28     0.36   95.13  4.26  5.70    0.89
# 444915      437631  6115  2020-12-29     0.00   96.29  3.41  4.37   -2.01
# 444916      441446  6115  2020-12-30     8.48   96.44  3.43  5.86   -1.93
# 444917      444917  6115  2020-12-31     0.81   96.09  4.85  5.64    2.78
#
#         T2MWET  T2M_MAX  ...    TS  WS10M  WS10M_MAX  WS10M_MIN  WS10M_RANGE  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
ab = pd.DataFrame(fd)
ab
# Out:
#         Unnamed: 0  fips        date  PRECTOT      PS  QV2M   T2M  T2MDEW  \
# 0                0  6001  2000-01-01     0.12   99.77  5.97  7.89    6.28
# 1             5753  6001  2000-01-02     0.00  100.53  4.46  6.04    2.01
# 2             4620  6001  2000-01-03     0.10  100.92  4.85  7.73    3.39
# 3             5120  6001  2000-01-04     0.27  100.90  6.11  8.36    6.77
# 4             5119  6001  2000-01-05     0.00  100.52  4.13  7.32    0.75
# ...            ...   ...         ...      ...     ...   ...   ...     ...
# 444913      437633  6115  2020-12-27     0.00   95.37  4.26  5.23    0.91
# 444914      437632  6115  2020-12-28     0.36   95.13  4.26  5.70    0.89
# 444915      437631  6115  2020-12-29     0.00   96.29  3.41  4.37   -2.01
# 444916      441446  6115  2020-12-30     8.48   96.44  3.43  5.86   -1.93
# 444917      444917  6115  2020-12-31     0.81   96.09  4.85  5.64    2.78
#
#         T2MWET  T2M_MAX  ...    TS  WS10M  WS10M_MAX  WS10M_MIN  WS10M_RANGE  \
# ...

# %%
rslt_df = ab[ab['fips'] == '6001'] 
    
print('\nResult dataframe :\n', rslt_df)
# Out:
# Result dataframe :
#  Empty DataFrame
# Columns: [Unnamed: 0, fips, date, PRECTOT, PS, QV2M, T2M, T2MDEW, T2MWET, T2M_MAX, T2M_MIN, T2M_RANGE, TS, WS10M, WS10M_MAX, WS10M_MIN, WS10M_RANGE, WS50M, WS50M_MAX, WS50M_MIN, WS50M_RANGE, score]
# Index: []
#
# [0 rows x 22 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
corr = ab.corr()
corr
# Out:
#              Unnamed: 0      fips   PRECTOT        PS      QV2M       T2M  \
# Unnamed: 0     1.000000  0.999851  0.001268  0.037251  0.077430 -0.024629
# fips           0.999851  1.000000  0.001157  0.037257  0.077325 -0.024406
# PRECTOT        0.001268  0.001157  1.000000 -0.039320  0.082097 -0.247112
# PS             0.037251  0.037257 -0.039320  1.000000  0.417007  0.281336
# QV2M           0.077430  0.077325  0.082097  0.417007  1.000000  0.414553
# T2M           -0.024629 -0.024406 -0.247112  0.281336  0.414553  1.000000
# T2MDEW         0.074025  0.073933  0.081737  0.555932  0.967396  0.417988
# T2MWET         0.073988  0.073901  0.080702  0.560933  0.968376  0.420715
# T2M_MAX       -0.037974 -0.037756 -0.324942  0.220423  0.298914  0.975557
# T2M_MIN       -0.003864 -0.003593 -0.166760  0.367738  0.526809  0.961613
# T2M_RANGE     -0.070658 -0.070597 -0.420664 -0.065034 -0.126893  0.628597
# TS            -0.028352 -0.028164 -0.231740  0.294944  0.447527  0.990499
# ...

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(ab.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(ab.columns)
ax.set_yticklabels(ab.columns)
plt.show()

# %%
fd.isnull().sum()/len(fd)*100
# Out:
# Unnamed: 0      0.000000
# fips            0.000000
# date            0.000000
# PRECTOT         0.000000
# PS              0.000000
# QV2M            0.000000
# T2M             0.000000
# T2MDEW          0.000000
# T2MWET          0.000000
# T2M_MAX         0.000000
# T2M_MIN         0.000000
# T2M_RANGE       0.000000
# TS              0.000000
# WS10M           0.000000
# WS10M_MAX       0.000000
# WS10M_MIN       0.000000
# WS10M_RANGE     0.000000
# WS50M           0.000000
# WS50M_MAX       0.000000
# WS50M_MIN       0.000000
# WS50M_RANGE     0.000000
# score          85.712423
# dtype: float64

# %%
#import required libraries
import pandas as pd
from datetime import datetime
#read the daily data file

#convert date column into datetime object
datetimes = pd.to_datetime(fd["date"])
print(datetimes)
# Out:
# 0        2000-01-01
# 1        2000-01-02
# 2        2000-01-03
# 3        2000-01-04
# 4        2000-01-05
#             ...
# 444913   2020-12-27
# 444914   2020-12-28
# 444915   2020-12-29
# 444916   2020-12-30
# 444917   2020-12-31
# Name: date, Length: 444918, dtype: datetime64[ns]

# %%
ef = pd.read_csv (r'C:\Users\shahb\OneDrive\Desktop\weekly_aggregated_data_ca_drought.csv')
print(ef)
# Out:
#        Unnamed: 0    fips    PRECTOT          PS      QV2M        T2M  \
# 0               0  6001.0   0.070000  100.561429  4.688571   7.165714
# 1               1  6001.0   1.260000  100.167143  6.457143   9.217143
# 2               2  6001.0   4.908571   99.798571  7.081429  10.751429
# 3               3  6001.0  11.604286   99.864286  6.640000   9.822857
# 4               4  6001.0   2.254286   99.908571  6.584286  10.104286
# ...           ...     ...        ...         ...       ...        ...
# 63563       63563  6115.0   0.000000   96.311429  3.632857   9.695714
# 63564       63564  6115.0   0.738571   96.130000  4.124286   9.118571
# 63565       63565  6115.0   9.255714   96.141429  4.602857   5.747143
# 63566       63566  6115.0   2.342857   96.298571  3.722857   6.907143
# 63567       63567  6115.0   3.968333   95.910000  4.365000   5.661667
#
#          T2MDEW    T2MWET    T2M_MAX   T2M_MIN  ...         TS     WS10M  \
# ...

# %%
b=ef.drop(['score','Unnamed: 0'], 1)
print(b)
# Out:
#          fips    PRECTOT          PS      QV2M        T2M    T2MDEW    T2MWET  \
# 0      6001.0   0.070000  100.561429  4.688571   7.165714  2.421429  2.460000
# 1      6001.0   1.260000  100.167143  6.457143   9.217143  7.348571  7.351429
# 2      6001.0   4.908571   99.798571  7.081429  10.751429  8.597143  8.598571
# 3      6001.0  11.604286   99.864286  6.640000   9.822857  7.608571  7.612857
# 4      6001.0   2.254286   99.908571  6.584286  10.104286  7.620000  7.620000
# ...       ...        ...         ...       ...        ...       ...       ...
# 63563  6115.0   0.000000   96.311429  3.632857   9.695714 -1.340000  2.475714
# 63564  6115.0   0.738571   96.130000  4.124286   9.118571  0.372857  4.744286
# 63565  6115.0   9.255714   96.141429  4.602857   5.747143  1.962857  3.854286
# 63566  6115.0   2.342857   96.298571  3.722857   6.907143 -0.958571  2.975714
# 63567  6115.0   3.968333   95.910000  4.365000   5.661667  1.065000  3.363333
#
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
#df=df.drop(['Item_Identifier', 'Outlet_Identifier'], axis=1)
model = RandomForestRegressor(random_state=1, max_depth=10)
b=pd.get_dummies(b)
model.fit(b,ef.score)
# Out:
# RandomForestRegressor(max_depth=10, random_state=1)

# %%
features = b.columns
importances = model.feature_importances_
indices = np.argsort(importances)[-18:]  # top 10 features
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
f = pd.read_csv (r'C:\Users\shahb\OneDrive\Desktop\ninety_days_aggregated_data_ca_drought.csv')
print(f)
# Out:
#        Unnamed: 0    fips   PRECTOT          PS      QV2M        T2M  \
# 0               0  6001.0  0.196000  100.487000  5.158000   7.692000
# 1               0  6001.0  1.709412  100.257059  5.701765   8.592941
# 2               0  6001.0  5.068333  100.105833  6.274583   9.290833
# 3               0  6001.0  4.312581  100.076129  6.227097   9.242903
# 4               0  6001.0  3.762632  100.067105  6.358947   9.557368
# ...           ...     ...       ...         ...       ...        ...
# 63563           0  6115.0  0.586000   95.797222  3.967889  16.987444
# 63564           0  6115.0  1.059778   95.826000  3.981444  15.774889
# 63565           0  6115.0  1.363333   95.881111  3.865667  14.584333
# 63566           0  6115.0  1.706778   95.900556  3.775444  13.172000
# 63567           0  6115.0  1.894186   95.929302  3.846860  11.910581
#
#          T2MDEW    T2MWET    T2M_MAX    T2M_MIN  ...         TS     WS10M  \
# ...

# %%
s=f.drop(['score','Unnamed: 0'], 1)
print(s)
# Out:
#          fips   PRECTOT          PS      QV2M        T2M    T2MDEW    T2MWET  \
# 0      6001.0  0.196000  100.487000  5.158000   7.692000  3.782000  3.810000
# 1      6001.0  1.709412  100.257059  5.701765   8.592941  5.245294  5.262941
# 2      6001.0  5.068333  100.105833  6.274583   9.290833  6.589167  6.601667
# 3      6001.0  4.312581  100.076129  6.227097   9.242903  6.543226  6.553871
# 4      6001.0  3.762632  100.067105  6.358947   9.557368  6.895263  6.903947
# ...       ...       ...         ...       ...        ...       ...       ...
# 63563  6115.0  0.586000   95.797222  3.967889  16.987444 -0.969000 -0.422778
# 63564  6115.0  1.059778   95.826000  3.981444  15.774889 -0.911556 -0.120444
# 63565  6115.0  1.363333   95.881111  3.865667  14.584333 -1.221556 -0.182556
# 63566  6115.0  1.706778   95.900556  3.775444  13.172000 -1.462889 -0.192333
# 63567  6115.0  1.894186   95.929302  3.846860  11.910581 -1.190465  0.204419
#
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
#df=df.drop(['Item_Identifier', 'Outlet_Identifier'], axis=1)
model = RandomForestRegressor(random_state=1, max_depth=10)
s=pd.get_dummies(s)
model.fit(s,f.score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-620262720e03> in <module>
#       2 #df=df.drop(['Item_Identifier', 'Outlet_Identifier'], axis=1)
#       3 model = RandomForestRegressor(random_state=1, max_depth=10)
# ----> 4 s=pd.get_dummies(s)
#       5 model.fit(s,f.score)
#
# NameError: name 's' is not defined

# %%
features = s.columns
importances = model.feature_importances_
indices = np.argsort(importances)[-18:]  # top 10 features
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='g', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-f53e3bc6fc14> in <module>
# ----> 1 features = s.columns
#       2 importances = model.feature_importances_
#       3 indices = np.argsort(importances)[-18:]  # top 10 features
#       4 plt.title('Feature Importances')
#       5 plt.barh(range(len(indices)), importances[indices], color='g', align='center')
#
# NameError: name 's' is not defined
